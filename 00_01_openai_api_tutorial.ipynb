# %% [markdown]
# ## 💳 مرحله ۲ — خرید اعتبار (برای کاربران ایران)
#
# از ایران نمی‌توان مستقیم به سرویس‌های پرداخت OpenAI دسترسی داشت. چند راه‌حل:
#
# ### روش اول — Numberland
# خرید API Credit از طریق واسطه ایرانی:
#
# 🔗 [https://numberland.ir/?ref=204551](https://numberland.ir/?ref=204551)
#
# ### روش دوم — IraniCard
#
# 🔗 [https://panel.iranicard.ir/login?redirect=%2Fdashboard%3FreferralCode%3D53928383](https://panel.iranicard.ir/login?redirect=%2Fdashboard%3FreferralCode%3D53928383)
#
# ---

# %%
from dotenv import load_dotenv
from openai import OpenAI
import os

load_dotenv()
api_key = os.getenv("SERVICE_API_KEY")
model = "openai/gpt-oss-20b"
base_url="https://api.groq.com/openai/v1"

# %%
from openai import OpenAI
import os
client = OpenAI(
    api_key=os.getenv("SERVICE_API_KEY"),
    base_url="https://api.groq.com/openai/v1",
)
response = client.responses.create(
    input="Explain the importance of fast language models",
    model="openai/gpt-oss-20b",
)
print(response.output_text)
# Out:
# ## Why “Fast” Language Models Matter
#
# When people talk about large language models (LLMs), the focus often falls on **size** (parameters, training data, accuracy). Yet the *speed* with which a model can read a prompt and spit out a response is just as critical in the real world. Fast models underpin a huge range of services, devices, and research workflows, and they enable LLMs to be a practical technology rather than a laboratory curiosity.  Below is a deep dive into why speed matters, how it’s measured, what trade‑offs it forces, and how the industry is addressing the challenge.
#
# ---
#
# ### 1. Key Performance Indicators for Speed
#
# | Metric | What it tells you | Typical impact |
# |--------|-------------------|----------------|
# | **Latency** (ms per token or per request) | How quickly a model can start giving an answer. | Determines user‑perceived responsiveness in chatbots, IDE assistants, or web search. |
# ...

# %%
response = client.chat.completions.create(
    model="openai/gpt-oss-20b",
    messages=[
        {"role": "system",
        "content": "Answer in Persian."},
        {"role": "user",
        "content": "capital of iran?"}
    ]
)

print(response.choices[0].message.content)

# اطلاعات مصرف توکن
usage = response.usage
print(f"توکن‌های ورودی  : {usage.prompt_tokens}")
print(f"توکن‌های خروجی : {usage.completion_tokens}")
print(f"مجموع توکن‌ها  : {usage.total_tokens}")
# Out:
# پایتخت ایران تهران است.
# توکن‌های ورودی  : 82
# توکن‌های خروجی : 54
# مجموع توکن‌ها  : 136
